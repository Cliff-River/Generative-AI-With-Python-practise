# %%
from groq import Groq
from dotenv import load_dotenv

load_dotenv(".env")

client = Groq()
completion = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
      {
        "role": "user",
        "content": "写一篇工作周报"
      }
    ],
    temperature=1,
    max_completion_tokens=8192,
    top_p=1,
    reasoning_effort="medium",
    stream=True,
    stop=None,
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# **工作周报**
# **姓名**：张三 | **部门**：技术研发部 | **岗位**：软件工程师 | **周次**：第 12 周 | **日期**：2025‑09‑26
#
# ---
#
# ### 1. 本周工作内容
#
# | 序号 | 任务 | 关键动作 | 完成情况 | 备注 |
# |------|------|----------|----------|------|
# | 1 | **项目 A‑UI 重构** | ① 重新设计首页布局；② 统一组件样式；③ 代码复用率提升 | ✅ 已完成 80% | 主要任务已完成，待后续测试 |
# | 2 | **Bug #324 修复** | ① 分析日志；② 调试定位；③ 编写单元测试 | ✅ 已修复 | 影响用户体验的关键缺陷已消除 |
# | 3 | **性能优化** | ① 对数据库查询进行索引优化；② 前端资源懒加载 | ✅ 预计提升 30% | 仍待性能监控确认 |
# | 4 | **团队协作** | ① 参加每日 Stand‑up；② 协助新人上手 | ✅ |  |
#
# **总体完成度**：95%（含预估工作量）
#
# ---
#
# ### 2. 遇到的问题与解决方案
#
# | 序号 | 问题描述 | 影响 | 解决方案 | 进度 |
# |------|----------|------|----------|------|
# | 1 | 项目 A‑UI 与后端接口不兼容 | 影响功能上线 | ① 与后端沟通接口调整；② 采用接口代理方案 | ✅ 已解决 |
# | 2 | 性能测试中出现缓存失效 | 影响性能提升 | ① 重构缓存策略；② 加入灰度发布 | ✅ 已解决，待监控 |
# | 3 | 部署脚本自动化失败 | 影响发布效率 | ① 修复脚本错误；② 添加 CI 监控 | ✅ 已修复 |
#
# ---
#
# ### 3. 下周工作计划
#
# 1. **项目 A‑UI**：完成剩余 20% 代码编写与手工测试；启动自动化回归测试。
# 2. **性能监控**：上线性能监控 dashboard，收集首批数据；根据数据调整缓存策略。
# 3. **团队培训**：准备“React 组件库复用”培训材料，帮助团队提升复用意识。
# 4. **Bug 跟进**：跟踪新产生的 5 条 Bug，确保 100% 在 48 小时内解决。
#
# ---
#
# ### 4. 需要支持与协助
#
# - **后端团队**：确认接口文档更新，及时反馈接口变更。
# - **运维团队**：协助部署性能监控插件，并提供日志分析建议。
# - **产品经理**：在下周会议前提供功能优先级评估，确保 UI 变更符合业务需求。
#
# ---
#
# ### 5. 其他事项
#
# - 本周参加了“技术前沿分享会”，了解了 GraphQL 在微服务中的应用，可考虑在未来项目中引入。
# - 个人学习时间投入约 6 小时，完成《Clean Architecture》相关章节，并已将部分设计模式应用到现有项目。
#
# ---
#
# **签名**：
# 张三（软件工程师）
# 2025‑09‑26
#
# ---
